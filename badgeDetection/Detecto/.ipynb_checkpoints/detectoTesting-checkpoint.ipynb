# %% [markdown]
# ### Output

# %%
from detecto.core import Model
from detecto.visualize import detect_video

model = Model()  # Initialize a pre-trained model
detect_video(model, 'input_video.mp4', 'output.avi')

# %% [markdown]
# ### training model

# %%
# from detecto.core import Model, Dataset

# dataset = Dataset('custom_dataset/')  # Load images and label data from the custom_dataset/ folder

# model = Model(['dog', 'cat', 'rabbit'])  # Train to predict dogs, cats, and rabbits
# model.fit(dataset)

# model.predict(...)

# %% [markdown]
# ### testing reading image

# %%
import matplotlib.pyplot as plt
from detecto.utils import read_image

image = read_image('images/20200530_120113R.jpg')
plt.imshow(image)
plt.show()

# %% [markdown]
# ### creating dataset object for Detecto

# %%
from detecto.core import Dataset


# If your images and labels are in separate folders
dataset = Dataset('images/train', 'images')
dataset[0]
# Out:
# (tensor([[[-0.6109, -0.6965, -0.7822,  ..., -0.4911, -0.4911, -0.4739],
#           [-0.5596, -0.6109, -0.6623,  ..., -0.4054, -0.4397, -0.5253],
#           [-0.5938, -0.6109, -0.6281,  ..., -0.4397, -0.4397, -0.4739],
#           ...,
#           [ 1.9578,  2.0092,  1.9578,  ..., -1.1075, -1.0562, -1.0219],
#           [ 1.9749,  2.0263,  1.9407,  ..., -1.1418, -1.0562, -0.9877],
#           [ 1.9407,  2.0605,  1.9578,  ..., -1.1932, -1.1075, -1.0390]],
#
#          [[-0.4601, -0.5476, -0.6352,  ..., -0.3375, -0.3375, -0.3200],
#           [-0.4076, -0.4601, -0.5126,  ..., -0.2500, -0.2850, -0.3725],
#           [-0.4426, -0.4601, -0.4776,  ..., -0.2850, -0.2850, -0.3200],
#           ...,
#           [ 1.0105,  1.0630,  1.0105,  ..., -1.0728, -1.0203, -0.9853],
#           [ 1.0280,  1.0805,  0.9930,  ..., -1.1078, -1.0203, -0.9503],
#           [ 0.9930,  1.1155,  1.0105,  ..., -1.1604, -1.0728, -1.0028]],
#
#          [[-0.3230, -0.4101, -0.4973,  ..., -0.1312, -0.1312, -0.1138],
#           [-0.2707, -0.3230, -0.3753,  ..., -0.0441, -0.0790, -0.1661],
#           [-0.3055, -0.3230, -0.3404,  ..., -0.0790, -0.0790, -0.1138],
#           ...,
#           [ 0.4265,  0.4788,  0.4265,  ..., -0.3753, -0.3230, -0.2881],
#           [ 0.4439,  0.4962,  0.4091,  ..., -0.4101, -0.3230, -0.2532],
#           [ 0.4091,  0.5311,  0.4265,  ..., -0.4624, -0.3753, -0.3055]]]),
#  {'boxes': tensor([[ 977, 1525, 1170, 1854]]), 'labels': 'Badge'})

# %% [markdown]
# ### Image Augmentation

# %%
from torchvision import transforms
from detecto.utils import normalize_transform

custom_transforms = transforms.Compose([
    transforms.ToPILImage(),
    # Note: all images with a size smaller than 800 will be scaled up in size
    transforms.Resize(800),
    transforms.RandomHorizontalFlip(0.5),
    transforms.ColorJitter(saturation=0.2),
    transforms.ToTensor(),  # required
    normalize_transform(),  # required
])
dataset = Dataset('images/train', transform=custom_transforms)

# %% [markdown]
# ### check dataset

# %%
from detecto.visualize import show_labeled_image

image, targets = dataset[0]
show_labeled_image(image, targets['boxes'], targets['labels'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-577c1d820648> in <module>
#       1 from detecto.visualize import show_labeled_image
#       2
# ----> 3 image, targets = dataset[0]
#       4 show_labeled_image(image, targets['boxes'], targets['labels'])
#
# ~\AppData\Roaming\Python\Python37\site-packages\detecto\core.py in __getitem__(self, idx)
#     146
#     147         # Read in the image from the file name in the 0th column
# --> 148         img_name = os.path.join(self._root_dir, self._csv.iloc[idx, 0])
#     149         image = read_image(img_name)
#     150
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1759                 except (KeyError, IndexError, AttributeError):
#    1760                     pass
# -> 1761             return self._getitem_tuple(key)
#    1762         else:
#    1763             # we by definition only have the 0th axis
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    2064     def _getitem_tuple(self, tup: Tuple):
#    2065
# -> 2066         self._has_valid_tuple(tup)
#    2067         try:
#    2068             return self._getitem_lowerdim(tup)
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     700                 raise IndexingError("Too many indexers")
#     701             try:
# --> 702                 self._validate_key(k, i)
#     703             except ValueError:
#     704                 raise ValueError(
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1991             return
#    1992         elif is_integer(key):
# -> 1993             self._validate_integer(key, axis)
#    1994         elif isinstance(key, tuple):
#    1995             # a tuple should already have been caught by this point
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2060         len_axis = len(self.obj._get_axis(axis))
#    2061         if key >= len_axis or key < -len_axis:
# -> 2062             raise IndexError("single positional indexer is out-of-bounds")
#    2063
#    2064     def _getitem_tuple(self, tup: Tuple):
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ### Train model on dataset

# %%
from detecto.core import DataLoader, Model

# Specify all unique labels you're trying to predict
your_labels = ['Badge', 'ML6 logo']
model = Model(your_labels)

model.fit(dataset, verbose=True)

# Alternatively, provide your own DataLoader to the fit method
loader = DataLoader(dataset, batch_size=2, shuffle=True)
model.fit(loader, verbose=True)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to C:\Users\jens/.cache\torch\checkpoints\fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# HBox(children=(FloatProgress(value=0.0, max=167502836.0), HTML(value='')))
# Epoch 1 of 10
# C:\Users\jens\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# ..\torch\csrc\utils\python_arg_parser.cpp:756: UserWarning: This overload of nonzero is deprecated:
# 	nonzero(Tensor input, *, Tensor out)
# Consider using one of the following signatures instead:
# 	nonzero(Tensor input, *, bool as_tuple)
# Epoch 2 of 10
# Epoch 3 of 10
# Epoch 4 of 10
# Epoch 5 of 10
# Epoch 6 of 10
# Epoch 7 of 10
# Epoch 8 of 10
# Epoch 9 of 10
# Epoch 10 of 10
# Epoch 1 of 10
# Epoch 2 of 10
# Epoch 3 of 10
# Epoch 4 of 10
# Epoch 5 of 10
# Epoch 6 of 10
# Epoch 7 of 10
# Epoch 8 of 10
# Epoch 9 of 10
# Epoch 10 of 10

# %%
val_dataset = Dataset('images/test')
losses = model.fit(dataset, val_dataset, epochs=15, learning_rate=0.01,
                   gamma=0.2, lr_step_size=5, verbose=True)

plt.plot(losses)
plt.show()

# %% [markdown]
# ### validate image

# %%
image = read_image('testImage.jpg')
predictions = model.predict(image)

images = []
# for i in range(4):
#     image, _ = val_dataset[i]
images.append(image)

top_predictions = model.predict_top(images)

print(predictions)
print(top_predictions)
# Out:
# (['Badge', 'ML6 logo'], tensor([[ 933.1851, 1764.8051, 1166.6805, 2129.7102],
#         [ 954.0410, 2069.2639, 1158.1251, 2108.5994]]), tensor([0.9514, 0.7476]))
# [(['ML6 logo', 'Badge'], tensor([[ 954.0410, 2069.2639, 1158.1251, 2108.5994],
#         [ 933.1851, 1764.8051, 1166.6805, 2129.7102]]), tensor([0.7476, 0.9514]))]

# %% [markdown]
# ### Run test

# %%
from detecto.visualize import plot_prediction_grid, detect_video, detect_live

plot_prediction_grid(model, images, dim=(1, 1), figsize=(8, 8))
#detect_video(model, 'your_input_video.mp4', 'your_output_file.avi')
#detect_live(model, score_filter=0.7)  # Note: may not work on VMs

# %% [markdown]
# ### save model

# %%
model.save('badgeDetectionV1.pth')

# %% [markdown]
# ### load model and live tryout

# %%
from detecto.core import DataLoader, Model
from detecto.visualize import plot_prediction_grid, detect_video, detect_live
labels = ['Badge', 'ML6 logo']
model = Model.load('badgeDetectionV1.pth', labels)
detect_live(model, score_filter=0.7)
# Out:
# C:\Users\jens\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# ..\torch\csrc\utils\python_arg_parser.cpp:756: UserWarning: This overload of nonzero is deprecated:
# 	nonzero(Tensor input, *, Tensor out)
# Consider using one of the following signatures instead:
# 	nonzero(Tensor input, *, bool as_tuple)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f9c32238f8a0> in <module>
#       3 labels = ['Badge', 'ML6 logo']
#       4 model = Model.load('badgeDetectionV1.pth', labels)
# ----> 5 detect_live(model, score_filter=0.7)
#
# ~\AppData\Roaming\Python\Python37\site-packages\detecto\visualize.py in detect_live(model, score_filter)
#      43             break
#      44
# ---> 45         labels, boxes, scores = model.predict(frame)
#      46
#      47         # Plot each box with its label and score
#
# ~\AppData\Roaming\Python\Python37\site-packages\detecto\core.py in predict(self, images)
#     320         is_single_image = not _is_iterable(images)
#     321         images = [images] if is_single_image else images
# --> 322         preds = self._get_raw_predictions(images)
#     323
#     324         results = []
#
# ~\AppData\Roaming\Python\Python37\site-packages\detecto\core.py in _get_raw_predictions(self, images)
#     276             images = [img.to(self._device) for img in images]
#     277
# --> 278             preds = self._model(images)
#     279             # Send predictions to CPU if not already
#     280             preds = [{k: v.to(torch.device('cpu')) for k, v in p.items()} for p in preds]
#
# ~\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~\AppData\Roaming\Python\Python37\site-packages\torchvision\models\detection\generalized_rcnn.py in forward(self, images, targets)
#      64             original_image_sizes.append((val[0], val[1]))
#      65
# ---> 66         images, targets = self.transform(images, targets)
#      67         features = self.backbone(images.tensors)
#      68         if isinstance(features, torch.Tensor):
#
# ~\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~\AppData\Roaming\Python\Python37\site-packages\torchvision\models\detection\transform.py in forward(self, images, targets)
#      43                                  "of shape [C, H, W], got {}".format(image.shape))
#      44             image = self.normalize(image)
# ---> 45             image, target_index = self.resize(image, target_index)
#      46             images[i] = image
#      47             if targets is not None and target_index is not None:
#
# ~\AppData\Roaming\Python\Python37\site-packages\torchvision\models\detection\transform.py in resize(self, image, target)
#      78         h, w = image.shape[-2:]
#      79         im_shape = torch.tensor(image.shape[-2:])
# ---> 80         min_size = float(torch.min(im_shape))
#      81         max_size = float(torch.max(im_shape))
#      82         if self.training:
#
# KeyboardInterrupt:
